# %%
import chromadb
client = chromadb.Client()

# %%
collection = client.create_collection("news_articles")

# %%
collection.add(
    ids=["id1","id2","id3","id4"],
    documents=[
        "Apples is leading in a smart phone game with iPhone sales up by 35%",
        "Tesla booked a minor profit of 1billion in Q2",
        "Apples are high in fiber",
        "SpaceX got NASA contract worth 10 billion $"
    ]
    
)

# %%
#fetch documents+ embeddings
data = collection.get(
    include = ["documents","embeddings","metadatas"]
)
# print(data["embeddings"])
#print embeddings
for i,emb in enumerate(data["embeddings"]):
    print(f"\nDOCUMENT {i+1}")
    print("Text:", data["documents"][i])
    print("Embedding length:", len(emb))
    print("First 10 values:", emb[:10])
# Out:
# DOCUMENT 1
# Text: Apples is leading in a smart phone game with iPhone sales up by 35%
# Embedding length: 384
# First 10 values: [ 0.02500495  0.02526503  0.07875554 -0.09541176 -0.00826487 -0.00600556
#   0.0205999   0.05580755  0.0214205   0.09768637]
#
# DOCUMENT 2
# Text: Tesla booked a minor profit of 1billion in Q2
# Embedding length: 384
# First 10 values: [ 0.02745215  0.09834614  0.01400571  0.05333579 -0.08353285 -0.02407161
#  -0.03164466  0.10860239  0.0205702   0.02728247]
#
# DOCUMENT 3
# Text: Apples are high in fiber
# Embedding length: 384
# First 10 values: [ 0.04670942 -0.06676949  0.04613708  0.05664061 -0.03314019 -0.04747868
#   0.01476874 -0.00506317  0.02271291  0.01502322]
#
# DOCUMENT 4
# Text: SpaceX got NASA contract worth 10 billion $
# Embedding length: 384
# First 10 values: [-0.02309863  0.03526217  0.06101783 -0.02734388 -0.08042093 -0.02970157
#   0.07421495  0.05592685  0.02907891  0.07048371]
